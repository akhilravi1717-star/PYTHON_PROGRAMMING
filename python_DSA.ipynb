# %% [markdown]
# # Data structre- user will define  the value more than one
#    - list
#    - tuple
#    - set
#    - dict

# %%
l = []

# %%
len(l)
# Out:
# 0

# %%
l = []
l.append(10)
l.append(20)
l.append(40)

# %%
len(l)
# Out:
# 3

# %%
l
# Out:
# [10, 20, 40]

# %%
id(l) #adress/memory location
# Out:
# 1820987612288

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
a = 5
type(a)
# Out:
# int

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# #####  IN list duplicate is allowed

# %%
l[:] # slicing
# Out:
# [10, 20, 40]

# %%
l[1]
# Out:
# 20

# %%
l[0]
# Out:
# 10

# %%
l[-1]
# Out:
# 40

# %%
l[-3]
# Out:
# 10

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 40]

# %%
l==l1
# Out:
# True

# %%
print(len(l))
print(len(l1))
# Out:
# 3
# 3

# %%
l1.append(2.3)
l1.append(True)
l1.append(1+2j)

# %%
l1
# Out:
# [10, 20, 40, 2.3, 2.3, True, (1+2j)]

# %%
l1.append(78)

# %%
l1
# Out:
# [10, 20, 40, 2.3, 2.3, True, (1+2j), 78, 78]

# %% [markdown]
# ####
# -append()-add the end
# - duplicate is allowed
# - slicing is allowed in the list
# - indexing is allowed in the list
# multiple data types can define the list
# - copy one list to another

# %%
#shift+tab =help

# %%
l1.count(78)
# Out:
# 2

# %%
l1.count(60)
# Out:
# 0

# %%
l.count(100)
# Out:
# 0

# %%
l
# Out:
# [10, 20, 40]

# %%
l1
# Out:
# [10, 20, 40, 2.3, 2.3, True, (1+2j), 78, 78]

# %%
l2 = l1.copy()

# %%
l2
# Out:
# [10, 20, 40, 2.3, 2.3, True, (1+2j), 78, 78]

# %%
l2.remove(78)

# %%
l2
# Out:
# [10, 20, 40, 2.3, 2.3, True, (1+2j), 78]

# %%
l2.remove(1+2j)

# %%
l2
# Out:
# [10, 20, 40, 2.3, 2.3, True, 78]

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
del l2

# %%
l1
# Out:
# [10, 20, 40, 2.3, 2.3, True, (1+2j), 78, 78]
